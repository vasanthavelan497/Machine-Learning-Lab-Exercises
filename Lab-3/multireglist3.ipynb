# %%
from sklearn import linear_model
from sklearn.datasets import make_regression
print("Multiple regression \n\n")   
      
X,y = make_regression(n_samples = 50,n_features=2,noise=0.1)
regr = linear_model.LinearRegression()
regr.fit(X,y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
print("\nAdjusted R Squared for Regression model:",regr.score(X,y))
# Out:
# Multiple regression
#
#
# Intercept:
#  -0.001288943115742125
# Coefficients:
#  [51.19060746 98.24361925]
#
# Adjusted R Squared for Regression model: 0.999999034096089
