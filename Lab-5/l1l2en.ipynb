# %%
from sklearn import linear_model
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression

x,y=make_regression(n_samples=50,n_features=1,noise=0.1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
print("Intercept:",regr.intercept_)
print("Coefficients:",regr.coef_)
print("Score of Logistic Reggression:")
print(regr.score(x,y))

#RIDGE REGRESSION
clf=RidgeCV(alphas=[1e-3,1e-2,1e-1,1]).fit(x,y)
clf.fit(x,y)
print("\nRidge Regression:")
print("Intercepts:",clf.intercept_)
print("Coefficients:",clf.coef_)
print("Score of Ridge Regression:")
print(clf.score(x,y))
print("Adjusted R Squared for Ridge Regression Model:",clf.score(x,y))

#LASSO REGRESSION
clf1=linear_model.Lasso(alpha=0.1).fit(x,y)
print("\nLasso Regression:")
print("Intercepts:",clf1.intercept_)
print("Coefficients:",clf1.coef_)
print("Score of Lasso Regression:")
print(clf1.score(x,y))
print("Adjusted R Squared for Lasso Regression Model:",clf1.score(x,y))

#ELASTICNET REGRESSION
clf2=ElasticNet(random_state=0).fit(x,y)
print("\nElasticNet Regression:")
print("Intercepts:",clf2.intercept_)
print("Coefficients:",clf2.coef_)
print("Score of ElasticNet Regression:")
print(clf2.score(x,y))
print("Adjusted R Squared for ElasticNet Regression Model:",clf2.score(x,y))
# Out:
# Intercept: 0.008943496218565272
# Coefficients: [75.6926008]
# Score of Logistic Reggression:
# 0.9999986413602334
#
# Ridge Regression:
# Intercepts: 0.009063274178215508
# Coefficients: [75.69142586]
# Score of Ridge Regression:
# 0.9999986411192824
# Adjusted R Squared for Ridge Regression Model: 0.9999986411192824
#
# Lasso Regression:
# Intercepts: 0.016855749204345294
# Coefficients: [75.61498656]
# Score of Lasso Regression:
# 0.9999975899423947
# Adjusted R Squared for Lasso Regression Model: 0.9999975899423947
#
# ElasticNet Regression:
# Intercepts: 2.1947509167464316
# Coefficients: [54.25120151]
# Score of ElasticNet Regression:
# 0.9197571848334913
# Adjusted R Squared for ElasticNet Regression Model: 0.9197571848334913
