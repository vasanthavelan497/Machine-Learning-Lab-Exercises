# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error
actual=np.array([10,20,30,40,50])
predicted=np.array([12,18,23,37,52])
mse=mean_squared_error(actual,predicted)
mae=mean_absolute_error(actual,predicted)
print("MEAN SQUARED ERROR(MSE) & MEAN ABSOLUTE ERROR(MAE):\n")
print("Actual values:",actual)
print("Predicted values:",predicted)
print("\nMean squared error(MSE):",mse)
print("Mean Absolute error(MAE):",mae)
# Out:
# MEAN SQUARED ERROR(MSE) & MEAN ABSOLUTE ERROR(MAE):
#
# Actual values: [10 20 30 40 50]
# Predicted values: [12 18 23 37 52]
#
# Mean squared error(MSE): 14.0
# Mean Absolute error(MAE): 3.2
